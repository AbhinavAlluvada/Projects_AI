# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

data = pd.read_csv('exoplanets_2018.csv')
val = data.columns
for i in val:
    print(i)
# Out:
# kepid
# kepoi_name
# kepler_name
# koi_disposition
# koi_pdisposition
# koi_score
# koi_fpflag_nt
# koi_fpflag_ss
# koi_fpflag_co
# koi_fpflag_ec
# koi_period
# koi_period_err1
# koi_period_err2
# koi_time0bk
# koi_time0bk_err1
# koi_time0bk_err2
# koi_impact
# koi_impact_err1
# koi_impact_err2
# koi_duration
# koi_duration_err1
# koi_duration_err2
# koi_depth
# koi_depth_err1
# koi_depth_err2
# koi_prad
# koi_prad_err1
# koi_prad_err2
# koi_teq
# koi_teq_err1
# koi_teq_err2
# koi_insol
# koi_insol_err1
# koi_insol_err2
# koi_model_snr
# koi_tce_plnt_num
# koi_tce_delivname
# koi_steff
# koi_steff_err1
# koi_steff_err2
# koi_slogg
# koi_slogg_err1
# koi_slogg_err2
# koi_srad
# koi_srad_err1
# koi_srad_err2
# ra
# dec
# koi_kepmag

# %%
data
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2     10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3     10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# ...        ...        ...           ...             ...              ...
# 9559  10090151  K07985.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9560  10128825  K07986.01           NaN       CANDIDATE        CANDIDATE
# 9561  10147276  K07987.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9562  10155286  K07988.01           NaN       CANDIDATE        CANDIDATE
# 9563  10156110  K07989.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# ...

# %%
data.isnull().sum()
# Out:
# kepid                   0
# kepoi_name              0
# kepler_name          7205
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       454
# koi_period_err2       454
# koi_time0bk             0
# koi_time0bk_err1      454
# koi_time0bk_err2      454
# koi_impact            363
# koi_impact_err1       454
# koi_impact_err2       454
# koi_duration            0
# koi_duration_err1     454
# koi_duration_err2     454
# koi_depth             363
# koi_depth_err1        454
# koi_depth_err2        454
# koi_prad              363
# koi_prad_err1         363
# koi_prad_err2         363
# koi_teq               363
# koi_teq_err1         9564
# koi_teq_err2         9564
# koi_insol             321
# koi_insol_err1        321
# koi_insol_err2        321
# koi_model_snr         363
# ...

# %%
data.drop(columns = ['koi_disposition' ,'koi_pdisposition' ,'kepler_name' ,'kepoi_name' ,'koi_tce_plnt_num' ],inplace = True)

# %%
data
# Out:
#          kepid  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0     10797460      1.000              0              0              0
# 1     10797460      0.969              0              0              0
# 2     10811496      0.000              0              0              0
# 3     10848459      0.000              0              1              0
# 4     10854555      1.000              0              0              0
# ...        ...        ...            ...            ...            ...
# 9559  10090151      0.000              0              1              1
# 9560  10128825      0.497              0              0              0
# 9561  10147276      0.021              0              0              1
# 9562  10155286      0.092              0              0              0
# 9563  10156110      0.000              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# ...

# %%
data.isnull().sum()
# Out:
# kepid                   0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       454
# koi_period_err2       454
# koi_time0bk             0
# koi_time0bk_err1      454
# koi_time0bk_err2      454
# koi_impact            363
# koi_impact_err1       454
# koi_impact_err2       454
# koi_duration            0
# koi_duration_err1     454
# koi_duration_err2     454
# koi_depth             363
# koi_depth_err1        454
# koi_depth_err2        454
# koi_prad              363
# koi_prad_err1         363
# koi_prad_err2         363
# koi_teq               363
# koi_teq_err1         9564
# koi_teq_err2         9564
# koi_insol             321
# koi_insol_err1        321
# koi_insol_err2        321
# koi_model_snr         363
# koi_tce_delivname     346
# koi_steff             363
# koi_steff_err1        468
# koi_steff_err2        483
# ...

# %%
data = data[data['koi_score']>0.95]

# %%
data
# Out:
#          kepid  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0     10797460      1.000              0              0              0
# 1     10797460      0.969              0              0              0
# 4     10854555      1.000              0              0              0
# 5     10872983      1.000              0              0              0
# 6     10872983      1.000              0              0              0
# ...        ...        ...            ...            ...            ...
# 9443  11904835      0.998              0              0              0
# 9495  12307496      1.000              0              0              0
# 9499  12602999      0.973              0              0              0
# 9514   9873004      0.959              0              0              0
# 9520   9906688      0.975              0              0              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# ...

# %%
data.isnull().sum()
# Out:
# kepid                   0
# koi_score               0
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1        11
# koi_period_err2        11
# koi_time0bk             0
# koi_time0bk_err1       11
# koi_time0bk_err2       11
# koi_impact              3
# koi_impact_err1        11
# koi_impact_err2        11
# koi_duration            0
# koi_duration_err1      11
# koi_duration_err2      11
# koi_depth               3
# koi_depth_err1         11
# koi_depth_err2         11
# koi_prad                3
# koi_prad_err1           3
# koi_prad_err2           3
# koi_teq                 3
# koi_teq_err1         3222
# koi_teq_err2         3222
# koi_insol               2
# koi_insol_err1          2
# koi_insol_err2          2
# koi_model_snr           3
# koi_tce_delivname       0
# koi_steff               3
# koi_steff_err1          6
# koi_steff_err2         18
# ...

# %%
data.drop(columns = ['koi_teq','koi_teq_err1','koi_teq_err2'],inplace = True)

# %%
data
# Out:
#          kepid  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0     10797460      1.000              0              0              0
# 1     10797460      0.969              0              0              0
# 4     10854555      1.000              0              0              0
# 5     10872983      1.000              0              0              0
# 6     10872983      1.000              0              0              0
# ...        ...        ...            ...            ...            ...
# 9443  11904835      0.998              0              0              0
# 9495  12307496      1.000              0              0              0
# 9499  12602999      0.973              0              0              0
# 9514   9873004      0.959              0              0              0
# 9520   9906688      0.975              0              0              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# ...

# %%
data.isnull().sum()
# Out:
# kepid                 0
# koi_score             0
# koi_fpflag_nt         0
# koi_fpflag_ss         0
# koi_fpflag_co         0
# koi_fpflag_ec         0
# koi_period            0
# koi_period_err1      11
# koi_period_err2      11
# koi_time0bk           0
# koi_time0bk_err1     11
# koi_time0bk_err2     11
# koi_impact            3
# koi_impact_err1      11
# koi_impact_err2      11
# koi_duration          0
# koi_duration_err1    11
# koi_duration_err2    11
# koi_depth             3
# koi_depth_err1       11
# koi_depth_err2       11
# koi_prad              3
# koi_prad_err1         3
# koi_prad_err2         3
# koi_insol             2
# koi_insol_err1        2
# koi_insol_err2        2
# koi_model_snr         3
# koi_tce_delivname     0
# koi_steff             3
# koi_steff_err1        6
# koi_steff_err2       18
# koi_slogg             3
# koi_slogg_err1        6
# koi_slogg_err2        6
# koi_srad              3
# koi_srad_err1         6
# koi_srad_err2         6
# ...

# %%
data.drop(columns = ['koi_time0bk','koi_time0bk_err1','koi_time0bk_err2'],inplace = True)

# %%
data
# Out:
#          kepid  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0     10797460      1.000              0              0              0
# 1     10797460      0.969              0              0              0
# 4     10854555      1.000              0              0              0
# 5     10872983      1.000              0              0              0
# 6     10872983      1.000              0              0              0
# ...        ...        ...            ...            ...            ...
# 9443  11904835      0.998              0              0              0
# 9495  12307496      1.000              0              0              0
# 9499  12602999      0.973              0              0              0
# 9514   9873004      0.959              0              0              0
# 9520   9906688      0.975              0              0              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_impact  \
# ...

# %%
data.drop(columns = ['koi_duration','koi_duration_err2','koi_duration_err1'],inplace = True)

# %%
data
# Out:
#          kepid  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0     10797460      1.000              0              0              0
# 1     10797460      0.969              0              0              0
# 4     10854555      1.000              0              0              0
# 5     10872983      1.000              0              0              0
# 6     10872983      1.000              0              0              0
# ...        ...        ...            ...            ...            ...
# 9443  11904835      0.998              0              0              0
# 9495  12307496      1.000              0              0              0
# 9499  12602999      0.973              0              0              0
# 9514   9873004      0.959              0              0              0
# 9520   9906688      0.975              0              0              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_impact  \
# ...

# %%
data.reset_index(drop = True)
# Out:
#          kepid  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0     10797460      1.000              0              0              0
# 1     10797460      0.969              0              0              0
# 2     10854555      1.000              0              0              0
# 3     10872983      1.000              0              0              0
# 4     10872983      1.000              0              0              0
# ...        ...        ...            ...            ...            ...
# 3217  11904835      0.998              0              0              0
# 3218  12307496      1.000              0              0              0
# 3219  12602999      0.973              0              0              0
# 3220   9873004      0.959              0              0              0
# 3221   9906688      0.975              0              0              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_impact  \
# ...

# %%
data.isnull().sum()
# Out:
# kepid                 0
# koi_score             0
# koi_fpflag_nt         0
# koi_fpflag_ss         0
# koi_fpflag_co         0
# koi_fpflag_ec         0
# koi_period            0
# koi_period_err1      11
# koi_period_err2      11
# koi_impact            3
# koi_impact_err1      11
# koi_impact_err2      11
# koi_depth             3
# koi_depth_err1       11
# koi_depth_err2       11
# koi_prad              3
# koi_prad_err1         3
# koi_prad_err2         3
# koi_insol             2
# koi_insol_err1        2
# koi_insol_err2        2
# koi_model_snr         3
# koi_tce_delivname     0
# koi_steff             3
# koi_steff_err1        6
# koi_steff_err2       18
# koi_slogg             3
# koi_slogg_err1        6
# koi_slogg_err2        6
# koi_srad              3
# koi_srad_err1         6
# koi_srad_err2         6
# ra                    0
# dec                   0
# koi_kepmag            0
# dtype: int64

# %%
data = data[((data['koi_fpflag_nt']==0) & (data['koi_fpflag_ss']==0) & (data['koi_fpflag_co']==0) & (data['koi_fpflag_ec']==0))]

# %%
data.drop(columns = data.columns[[2,3,4,5]],inplace = True)

# %%
data.reset_index(drop = True,inplace = True)

# %%
data
# Out:
#          kepid  koi_score  koi_period  koi_period_err1  koi_period_err2  \
# 0     10797460      1.000    9.488036     2.780000e-05    -2.780000e-05
# 1     10797460      0.969   54.418383     2.480000e-04    -2.480000e-04
# 2     10854555      1.000    2.525592     3.760000e-06    -3.760000e-06
# 3     10872983      1.000   11.094321     2.040000e-05    -2.040000e-05
# 4     10872983      1.000    4.134435     1.050000e-05    -1.050000e-05
# ...        ...        ...         ...              ...              ...
# 3142  11904835      0.998    9.464041     2.800000e-04    -2.800000e-04
# 3143  12307496      1.000    0.805942     8.190000e-07    -8.190000e-07
# 3144  12602999      0.973    8.276603     3.310000e-04    -3.310000e-04
# 3145   9873004      0.959    1.985146     1.190000e-05    -1.190000e-05
# 3146   9906688      0.975    5.825617     8.720000e-05    -8.720000e-05
#
#       koi_impact  koi_impact_err1  koi_impact_err2  koi_depth  koi_depth_err1  \
# ...

# %%
for i in data.columns:
    print(i)
# Out:
# kepid
# koi_score
# koi_period
# koi_period_err1
# koi_period_err2
# koi_impact
# koi_impact_err1
# koi_impact_err2
# koi_depth
# koi_depth_err1
# koi_depth_err2
# koi_prad
# koi_prad_err1
# koi_prad_err2
# koi_insol
# koi_insol_err1
# koi_insol_err2
# koi_model_snr
# koi_tce_delivname
# koi_steff
# koi_steff_err1
# koi_steff_err2
# koi_slogg
# koi_slogg_err1
# koi_slogg_err2
# koi_srad
# koi_srad_err1
# koi_srad_err2
# ra
# dec
# koi_kepmag

# %%
data.isnull().sum()
# Out:
# kepid                 0
# koi_score             0
# koi_period            0
# koi_period_err1      11
# koi_period_err2      11
# koi_impact            3
# koi_impact_err1      11
# koi_impact_err2      11
# koi_depth             3
# koi_depth_err1       11
# koi_depth_err2       11
# koi_prad              3
# koi_prad_err1         3
# koi_prad_err2         3
# koi_insol             2
# koi_insol_err1        2
# koi_insol_err2        2
# koi_model_snr         3
# koi_tce_delivname     0
# koi_steff             3
# koi_steff_err1        4
# koi_steff_err2       16
# koi_slogg             3
# koi_slogg_err1        4
# koi_slogg_err2        4
# koi_srad              3
# koi_srad_err1         4
# koi_srad_err2         4
# ra                    0
# dec                   0
# koi_kepmag            0
# dtype: int64

# %%
plt.scatter(data.index,data['koi_period_err1'])
plt.scatter(data.index,data['koi_period_err2'])
plt.yticks([0.003,0.002,0.001,0.0005,0.000,-0.0005,-0.001,-0.002,-0.003])
plt.axhline(y=0.0005,color = 'red')
plt.axhline(y=-0.0005,color = 'red')
plt.show()

# %%
data = data[((data['koi_period_err1']<0.0005) & (data['koi_period_err2']>-0.0005)) ]

# %%
data.isnull().sum()
# Out:
# kepid                 0
# koi_score             0
# koi_period            0
# koi_period_err1       0
# koi_period_err2       0
# koi_impact            0
# koi_impact_err1       0
# koi_impact_err2       0
# koi_depth             0
# koi_depth_err1        0
# koi_depth_err2        0
# koi_prad              0
# koi_prad_err1         0
# koi_prad_err2         0
# koi_insol             0
# koi_insol_err1        0
# koi_insol_err2        0
# koi_model_snr         0
# koi_tce_delivname     0
# koi_steff             0
# koi_steff_err1        1
# koi_steff_err2       13
# koi_slogg             0
# koi_slogg_err1        1
# koi_slogg_err2        1
# koi_srad              0
# koi_srad_err1         1
# koi_srad_err2         1
# ra                    0
# dec                   0
# koi_kepmag            0
# dtype: int64

# %%
sns.heatmap(data[['koi_steff_err2']])
plt.show()

# %%
plt.scatter(data.index,data['koi_steff_err2'])
plt.yticks([0,-60,-75,-90,-100,-200,-240,-250,-300,-400,-500])
plt.axhline(y=-60,color = 'red')
plt.axhline(y=-240,color = 'red')
plt.show()

# %%
data = data[((data['koi_steff_err2']<-60) & (data['koi_steff_err2']>-240))]

# %%
data
# Out:
#          kepid  koi_score  koi_period  koi_period_err1  koi_period_err2  \
# 0     10797460      1.000    9.488036     2.780000e-05    -2.780000e-05
# 1     10797460      0.969   54.418383     2.480000e-04    -2.480000e-04
# 2     10854555      1.000    2.525592     3.760000e-06    -3.760000e-06
# 3     10872983      1.000   11.094321     2.040000e-05    -2.040000e-05
# 4     10872983      1.000    4.134435     1.050000e-05    -1.050000e-05
# ...        ...        ...         ...              ...              ...
# 3142  11904835      0.998    9.464041     2.800000e-04    -2.800000e-04
# 3143  12307496      1.000    0.805942     8.190000e-07    -8.190000e-07
# 3144  12602999      0.973    8.276603     3.310000e-04    -3.310000e-04
# 3145   9873004      0.959    1.985146     1.190000e-05    -1.190000e-05
# 3146   9906688      0.975    5.825617     8.720000e-05    -8.720000e-05
#
#       koi_impact  koi_impact_err1  koi_impact_err2  koi_depth  koi_depth_err1  \
# ...

# %%
data.isnull().sum()
# Out:
# kepid                0
# koi_score            0
# koi_period           0
# koi_period_err1      0
# koi_period_err2      0
# koi_impact           0
# koi_impact_err1      0
# koi_impact_err2      0
# koi_depth            0
# koi_depth_err1       0
# koi_depth_err2       0
# koi_prad             0
# koi_prad_err1        0
# koi_prad_err2        0
# koi_insol            0
# koi_insol_err1       0
# koi_insol_err2       0
# koi_model_snr        0
# koi_tce_delivname    0
# koi_steff            0
# koi_steff_err1       0
# koi_steff_err2       0
# koi_slogg            0
# koi_slogg_err1       0
# koi_slogg_err2       0
# koi_srad             0
# koi_srad_err1        0
# koi_srad_err2        0
# ra                   0
# dec                  0
# koi_kepmag           0
# dtype: int64

# %%
print(data.isnull().values.all())
# Out:
# False

# %%
data['Time'] = ((data['koi_period'] + data['koi_period_err1']) + (data['koi_period'] + data['koi_period_err2']))/2

# %%
data.drop(columns = ['koi_period','koi_period_err1','koi_period_err2'],inplace = True)

# %%
data.columns
# Out:
# Index(['kepid', 'koi_score', 'koi_impact', 'koi_impact_err1',
#        'koi_impact_err2', 'koi_depth', 'koi_depth_err1', 'koi_depth_err2',
#        'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag', 'Time'],
#       dtype='object')

# %%
data['Impact'] = ((data['koi_impact'] + data['koi_impact_err1']) + (data['koi_impact'] + data['koi_impact_err2']))/2
data['Depth'] = ((data['koi_depth'] + data['koi_depth_err1']) + (data['koi_depth'] + data['koi_depth_err2']))/2
data['Radius'] = ((data['koi_prad'] + data['koi_prad_err1']) + (data['koi_prad'] + data['koi_prad_err2']))/2
data['Energy'] = ((data['koi_insol'] + data['koi_insol_err1']) + (data['koi_insol'] + data['koi_insol_err2']))/2
data['Star_Stability'] = ((data['koi_slogg'] + data['koi_slogg_err1']) + (data['koi_slogg'] + data['koi_slogg_err2']))/2
data['Temperature'] = ((data['koi_steff'] + data['koi_steff_err1']) + (data['koi_steff'] + data['koi_steff_err2']))/2

# %%
data
# Out:
#          kepid  koi_score  koi_impact  koi_impact_err1  koi_impact_err2  \
# 0     10797460      1.000       0.146            0.318           -0.146
# 1     10797460      0.969       0.586            0.059           -0.443
# 2     10854555      1.000       0.701            0.235           -0.478
# 3     10872983      1.000       0.538            0.030           -0.428
# 4     10872983      1.000       0.762            0.139           -0.532
# ...        ...        ...         ...              ...              ...
# 3142  11904835      0.998       0.048            0.420           -0.048
# 3143  12307496      1.000       1.339            9.378           -0.063
# 3144  12602999      0.973       0.638            0.007           -0.486
# 3145   9873004      0.959       0.126            0.326           -0.126
# 3146   9906688      0.975       0.635            0.220           -0.434
#
#       koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  ...  \
# ...

# %%
boom = []
for i in data.columns:
    boom.append(i)
boom = boom[2:28].copy()

# %%
boom
# Out:
# ['koi_impact',
#  'koi_impact_err1',
#  'koi_impact_err2',
#  'koi_depth',
#  'koi_depth_err1',
#  'koi_depth_err2',
#  'koi_prad',
#  'koi_prad_err1',
#  'koi_prad_err2',
#  'koi_insol',
#  'koi_insol_err1',
#  'koi_insol_err2',
#  'koi_model_snr',
#  'koi_tce_delivname',
#  'koi_steff',
#  'koi_steff_err1',
#  'koi_steff_err2',
#  'koi_slogg',
#  'koi_slogg_err1',
#  'koi_slogg_err2',
#  'koi_srad',
#  'koi_srad_err1',
#  'koi_srad_err2',
#  'ra',
#  'dec',
#  'koi_kepmag']

# %%
data.drop(columns = boom,inplace = True)

# %%
data
# Out:
#          kepid  koi_score       Time  Impact   Depth  Radius    Energy  \
# 0     10797460      1.000   9.488036  0.2320   616.0   2.315    99.990
# 1     10797460      0.969  54.418383  0.3940   875.0   2.895     9.735
# 2     10854555      1.000   2.525592  0.5795   603.0   3.015  1206.205
# 3     10872983      1.000  11.094321  0.3390  1520.0   4.325   152.885
# 4     10872983      1.000   4.134435  0.5655   686.0   3.070   569.465
# ...        ...        ...        ...     ...     ...     ...       ...
# 3142  11904835      0.998   9.464041  0.2340   210.0   1.400   151.045
# 3143  12307496      1.000   0.805942  5.9965  3180.0  29.985  1246.825
# 3144  12602999      0.973   8.276603  0.3985    73.1   2.265  1564.800
# 3145   9873004      0.959   1.985146  0.2260   233.0   1.365   809.140
# 3146   9906688      0.975   5.825617  0.5280   143.0   1.315   348.785
#
#       Star_Stability  Temperature
# 0             4.4510       5455.0
# 1             4.4510       5455.0
# ...

# %%
data.drop(['koi_score'],axis =1,inplace = True)

# %%
data
# Out:
#          kepid       Time  Impact   Depth  Radius    Energy  Star_Stability  \
# 0     10797460   9.488036  0.2320   616.0   2.315    99.990          4.4510
# 1     10797460  54.418383  0.3940   875.0   2.895     9.735          4.4510
# 2     10854555   2.525592  0.5795   603.0   3.015  1206.205          4.3680
# 3     10872983  11.094321  0.3390  1520.0   4.325   152.885          4.3985
# 4     10872983   4.134435  0.5655   686.0   3.070   569.465          4.3985
# ...        ...        ...     ...     ...     ...       ...             ...
# 3142  11904835   9.464041  0.2340   210.0   1.400   151.045          4.4500
# 3143  12307496   0.805942  5.9965  3180.0  29.985  1246.825          4.6090
# 3144  12602999   8.276603  0.3985    73.1   2.265  1564.800          3.8570
# 3145   9873004   1.985146  0.2260   233.0   1.365   809.140          4.5005
# 3146   9906688   5.825617  0.5280   143.0   1.315   348.785          4.3915
#
#       Temperature
# 0          5455.0
# ...

# %%
plt.scatter(data.index,data['Time'])
plt.show()

# %%
figs , ax = plt.subplots(7,1,figsize= (10,20))
ax[0].scatter(data.index,data['Time'])
ax[0].set_title('Time')
ax[0].axhline(y=60,color = 'red')
ax[1].scatter(data.index,data['Impact'])
ax[1].set_title('Impact')
ax[1].axhline(y=3,color = 'red')
ax[2].scatter(data.index,data['Depth'])
ax[2].set_title('Depth')
ax[2].axhline(y=60,color = 'red')
ax[3].scatter(data.index,data['Radius'])
ax[3].set_title('Radius')
ax[3].axhline(y=60,color = 'red')
ax[4].scatter(data.index,data['Energy'])
ax[4].set_title('Energy')
ax[4].axhline(y=60,color = 'red')
ax[5].scatter(data.index,data['Temperature'])
ax[5].set_title('Temperature')
ax[5].axhline(y=60,color = 'red')
ax[6].scatter(data.index,data['Star_Stability'])
ax[6].set_title('Star_Stability')
ax[6].axhline(y=60,color = 'red')

plt.tight_layout()
plt.show()

# %%
import numpy as np

Q1 = data['Depth'].quantile(0.25)
Q3 = data['Depth'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier limits (1.5 * IQR rule)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")
print(data['Depth'].max())
# Out:
# Lower Bound: -741.375, Upper Bound: 1701.625
# 37500.0

# %%
print(data['Depth'].min())
print(data['Depth'].max())
# Out:
# 15.5
# 37500.0

# %%
data1 = data.iloc[:,1:8].copy()

# %%
data1
# Out:
#            Time  Impact   Depth  Radius    Energy  Star_Stability  Temperature
# 0      9.488036  0.2320   616.0   2.315    99.990          4.4510       5455.0
# 1     54.418383  0.3940   875.0   2.895     9.735          4.4510       5455.0
# 2      2.525592  0.5795   603.0   3.015  1206.205          4.3680       6010.0
# 3     11.094321  0.3390  1520.0   4.325   152.885          4.3985       6024.5
# 4      4.134435  0.5655   686.0   3.070   569.465          4.3985       6024.5
# ...         ...     ...     ...     ...       ...             ...          ...
# 3142   9.464041  0.2340   210.0   1.400   151.045          4.4500       5959.0
# 3143   0.805942  5.9965  3180.0  29.985  1246.825          4.6090       5022.0
# 3144   8.276603  0.3985    73.1   2.265  1564.800          3.8570       6777.0
# 3145   1.985146  0.2260   233.0   1.365   809.140          4.5005       5572.5
# 3146   5.825617  0.5280   143.0   1.315   348.785          4.3915       5990.0
#
# [2744 rows x 7 columns]

# %%
sns.boxplot(data = data[['Time','Depth','Impact','Energy','Temperature','Radius','Star_Stability']])
plt.xticks(rotation = 45)
plt.yticks([0,10000,20000,30000,40000,50000,100000])
plt.show()

# %%
sns.boxplot(data['Time'])
plt.show()

# %%
data1 = data1[data1['Star_Stability']>4]

# %%
data.to_csv('Filter.csv')

# %%
data1
# Out:
#            Time  Impact   Depth  Radius    Energy  Star_Stability  Temperature
# 0      9.488036  0.2320   616.0   2.315    99.990          4.4510       5455.0
# 1     54.418383  0.3940   875.0   2.895     9.735          4.4510       5455.0
# 2      2.525592  0.5795   603.0   3.015  1206.205          4.3680       6010.0
# 3     11.094321  0.3390  1520.0   4.325   152.885          4.3985       6024.5
# 4      4.134435  0.5655   686.0   3.070   569.465          4.3985       6024.5
# ...         ...     ...     ...     ...       ...             ...          ...
# 3141   0.862329  0.2285   141.0   1.190  3363.095          4.4500       5785.5
# 3142   9.464041  0.2340   210.0   1.400   151.045          4.4500       5959.0
# 3143   0.805942  5.9965  3180.0  29.985  1246.825          4.6090       5022.0
# 3145   1.985146  0.2260   233.0   1.365   809.140          4.5005       5572.5
# 3146   5.825617  0.5280   143.0   1.315   348.785          4.3915       5990.0
#
# [2650 rows x 7 columns]

# %%
plt.scatter(data.index,data['Energy'])
plt.axhline(y = 10500,c='r')
plt.show()

# %%
plt.scatter(data1.index,data1['Star_Stability'])
plt.axhline(y = 4,c='r')
plt.show()

# %%
data1
# Out:
#            Time  Impact   Depth  Radius    Energy  Star_Stability  Temperature
# 0      9.488036  0.2320   616.0   2.315    99.990          4.4510       5455.0
# 1     54.418383  0.3940   875.0   2.895     9.735          4.4510       5455.0
# 2      2.525592  0.5795   603.0   3.015  1206.205          4.3680       6010.0
# 3     11.094321  0.3390  1520.0   4.325   152.885          4.3985       6024.5
# 4      4.134435  0.5655   686.0   3.070   569.465          4.3985       6024.5
# ...         ...     ...     ...     ...       ...             ...          ...
# 3141   0.862329  0.2285   141.0   1.190  3363.095          4.4500       5785.5
# 3142   9.464041  0.2340   210.0   1.400   151.045          4.4500       5959.0
# 3143   0.805942  5.9965  3180.0  29.985  1246.825          4.6090       5022.0
# 3145   1.985146  0.2260   233.0   1.365   809.140          4.5005       5572.5
# 3146   5.825617  0.5280   143.0   1.315   348.785          4.3915       5990.0
#
# [2650 rows x 7 columns]

# %%
plt.plot(data1['Energy'])
plt.show()

# %%
data1.drop(['Impact'],axis = 1,inplace = True)

# %%
data1.to_csv('Filter2.csv')

# %%
data1.drop(['Depth'],axis =1,inplace = True)

# %%
data1
# Out:
#            Time  Radius    Energy  Star_Stability  Temperature
# 0      9.488036   2.315    99.990          4.4510       5455.0
# 1     54.418383   2.895     9.735          4.4510       5455.0
# 2      2.525592   3.015  1206.205          4.3680       6010.0
# 3     11.094321   4.325   152.885          4.3985       6024.5
# 4      4.134435   3.070   569.465          4.3985       6024.5
# ...         ...     ...       ...             ...          ...
# 3141   0.862329   1.190  3363.095          4.4500       5785.5
# 3142   9.464041   1.400   151.045          4.4500       5959.0
# 3143   0.805942  29.985  1246.825          4.6090       5022.0
# 3145   1.985146   1.365   809.140          4.5005       5572.5
# 3146   5.825617   1.315   348.785          4.3915       5990.0
#
# [2650 rows x 5 columns]

# %%
data1.corr()
# Out:
#                     Time    Radius    Energy  Star_Stability  Temperature
# Time            1.000000  0.268497 -0.210549       -0.068531     0.058136
# Radius          0.268497  1.000000 -0.019361       -0.118352     0.116387
# Energy         -0.210549 -0.019361  1.000000       -0.231355     0.167965
# Star_Stability -0.068531 -0.118352 -0.231355        1.000000    -0.782381
# Temperature     0.058136  0.116387  0.167965       -0.782381     1.000000

# %%
data1
# Out:
#            Time  Radius    Energy  Star_Stability  Temperature
# 0      9.488036   2.315    99.990          4.4510       5455.0
# 1     54.418383   2.895     9.735          4.4510       5455.0
# 2      2.525592   3.015  1206.205          4.3680       6010.0
# 3     11.094321   4.325   152.885          4.3985       6024.5
# 4      4.134435   3.070   569.465          4.3985       6024.5
# ...         ...     ...       ...             ...          ...
# 3141   0.862329   1.190  3363.095          4.4500       5785.5
# 3142   9.464041   1.400   151.045          4.4500       5959.0
# 3143   0.805942  29.985  1246.825          4.6090       5022.0
# 3145   1.985146   1.365   809.140          4.5005       5572.5
# 3146   5.825617   1.315   348.785          4.3915       5990.0
#
# [2650 rows x 5 columns]

# %%
data1.to_csv('bankai.csv')

# %%
val = data1['Radius']

# %%
plt.plot(val)

# %%
sns.boxplot(val)
plt.show()

# %%
q1 = val.quantile(0.20)
q2 = val.quantile(0.80)
iq = q2-q1
lower = iq*q1
upper = iq*q2
print(f"Lower bound: {lower}, upper bound: {upper}")
# Out:
# Lower bound: 2.2389000000000014, upper bound: 5.322436000000004

# %%
plt.scatter(val.index,val)
plt.axhline(y=upper,c='r')
plt.show()

# %%
data1
# Out:
#            Time  Radius    Energy  Star_Stability  Temperature
# 0      9.488036   2.315    99.990          4.4510       5455.0
# 1     54.418383   2.895     9.735          4.4510       5455.0
# 2      2.525592   3.015  1206.205          4.3680       6010.0
# 3     11.094321   4.325   152.885          4.3985       6024.5
# 4      4.134435   3.070   569.465          4.3985       6024.5
# ...         ...     ...       ...             ...          ...
# 3141   0.862329   1.190  3363.095          4.4500       5785.5
# 3142   9.464041   1.400   151.045          4.4500       5959.0
# 3143   0.805942  29.985  1246.825          4.6090       5022.0
# 3145   1.985146   1.365   809.140          4.5005       5572.5
# 3146   5.825617   1.315   348.785          4.3915       5990.0
#
# [2650 rows x 5 columns]

# %%
sns.histplot(data1['Energy'],bins = 30,kde = True)
plt.show()

# %%
data1['Energy'] = np.log1p(data['Energy'])

# %%
data1.head(50)
# Out:
#          Time  Radius    Energy  Star_Stability  Temperature
# 0    9.488036   2.315  4.615022          4.4510       5455.0
# 1   54.418383   2.895  2.373509          4.4510       5455.0
# 2    2.525592   3.015  7.096063          4.3680       6010.0
# 3   11.094321   4.325  5.036206          4.3985       6024.5
# 4    4.134435   3.070  6.346452          4.3985       6024.5
# 5    2.566589   1.765  6.981559          4.3985       6024.5
# 6   16.068647   5.625  3.422633          4.5125       5027.0
# 7    3.522498  14.590  7.155431          4.1740       6212.5
# 8    3.709214   1.185  6.282584          4.3925       5827.0
# 9    9.273582   2.450  3.766882          4.5980       4848.5
# 10   6.029303   2.905  3.994524          4.6300       4537.0
# 11   5.349554   2.510  5.124440          4.4665       5189.0
# 12   3.941052   1.675  5.526568          4.4665       5189.0
# 13   8.109048   1.285  4.574041          4.4665       5189.0
# ...

# %%
plt.plot(data1['Energy'])

# %%
q1 = data1['Energy'].quantile(0.25)
q2 = data1['Energy'].quantile(0.75)
iq = q2-q1
iq
# Out:
# 2.209673566974383

# %%
sns.histplot(data1['Energy'],bins = 30,kde = True)
plt.show()

# %%
data1.to_csv('bankai2.csv')

# %%
corr = data1.corr()

# %%
sns.heatmap(corr,alpha = 0.5)
plt.show()

# %%
data1
# Out:
#            Time  Radius    Energy  Star_Stability  Temperature
# 0      9.488036   2.315  4.615022          4.4510       5455.0
# 1     54.418383   2.895  2.373509          4.4510       5455.0
# 2      2.525592   3.015  7.096063          4.3680       6010.0
# 3     11.094321   4.325  5.036206          4.3985       6024.5
# 4      4.134435   3.070  6.346452          4.3985       6024.5
# ...         ...     ...       ...             ...          ...
# 3141   0.862329   1.190  8.120914          4.4500       5785.5
# 3142   9.464041   1.400  5.024177          4.4500       5959.0
# 3143   0.805942  29.985  7.129157          4.6090       5022.0
# 3145   1.985146   1.365  6.697207          4.5005       5572.5
# 3146   5.825617   1.315  5.857319          4.3915       5990.0
#
# [2650 rows x 5 columns]

# %%
plt.scatter(data1.index,data1['Radius'])
plt.axhline(y=10,c='r')
plt.show()

# %%
data1 = data1[data1['Radius']<12]

# %%
data1
# Out:
#            Time  Radius    Energy  Star_Stability  Temperature
# 0      9.488036   2.315  4.615022          4.4510       5455.0
# 1     54.418383   2.895  2.373509          4.4510       5455.0
# 2      2.525592   3.015  7.096063          4.3680       6010.0
# 3     11.094321   4.325  5.036206          4.3985       6024.5
# 4      4.134435   3.070  6.346452          4.3985       6024.5
# ...         ...     ...       ...             ...          ...
# 3139   9.910579   1.305  5.374954          4.3670       6170.5
# 3141   0.862329   1.190  8.120914          4.4500       5785.5
# 3142   9.464041   1.400  5.024177          4.4500       5959.0
# 3145   1.985146   1.365  6.697207          4.5005       5572.5
# 3146   5.825617   1.315  5.857319          4.3915       5990.0
#
# [2599 rows x 5 columns]

# %%
plt.scatter(data1.index,data1['Radius'])
plt.axhline(y=10,c='r')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
plt.scatter(data1.index,data1['Temperature'])
plt.show()

# %%
scaler = StandardScaler()
data1[["Star_Stability", "Temperature"]] = scaler.fit_transform(data1[["Star_Stability", "Temperature"]])

# %%
plt.scatter(data1.index,data1['Temperature'])
plt.show()

# %%
data1
# Out:
#            Time  Radius    Energy  Star_Stability  Temperature
# 0      9.488036   2.315  4.615022        0.136131    -0.022389
# 1     54.418383   2.895  2.373509        0.136131    -0.022389
# 2      2.525592   3.015  7.096063       -0.361591     0.845415
# 3     11.094321   4.325  5.036206       -0.178693     0.868087
# 4      4.134435   3.070  6.346452       -0.178693     0.868087
# ...         ...     ...       ...             ...          ...
# 3139   9.910579   1.305  5.374954       -0.367587     1.096374
# 3141   0.862329   1.190  8.120914        0.130135     0.494384
# 3142   9.464041   1.400  5.024177        0.130135     0.765671
# 3145   1.985146   1.365  6.697207        0.432966     0.161335
# 3146   5.825617   1.315  5.857319       -0.220669     0.814143
#
# [2599 rows x 5 columns]

# %%
data1.reset_index(drop = True,inplace =True)

# %%
data1
# Out:
#            Time  Radius    Energy  Star_Stability  Temperature
# 0      9.488036   2.315  4.615022        0.136131    -0.022389
# 1     54.418383   2.895  2.373509        0.136131    -0.022389
# 2      2.525592   3.015  7.096063       -0.361591     0.845415
# 3     11.094321   4.325  5.036206       -0.178693     0.868087
# 4      4.134435   3.070  6.346452       -0.178693     0.868087
# ...         ...     ...       ...             ...          ...
# 2594   9.910579   1.305  5.374954       -0.367587     1.096374
# 2595   0.862329   1.190  8.120914        0.130135     0.494384
# 2596   9.464041   1.400  5.024177        0.130135     0.765671
# 2597   1.985146   1.365  6.697207        0.432966     0.161335
# 2598   5.825617   1.315  5.857319       -0.220669     0.814143
#
# [2599 rows x 5 columns]

# %%
data1.to_csv('bankai.csv')

# %%
scaler = StandardScaler()
data1[["Time", "Radius","Energy"]] = scaler.fit_transform(data1[["Time", "Radius","Energy"]])

# %%
data1.to_csv('bankai.csv')

# %%
data1.corr()
# Out:
#                     Time    Radius    Energy  Star_Stability  Temperature
# Time            1.000000  0.483992 -0.574124       -0.069489     0.058334
# Radius          0.483992  1.000000 -0.261211       -0.144379     0.117773
# Energy         -0.574124 -0.261211  1.000000       -0.446620     0.448225
# Star_Stability -0.069489 -0.144379 -0.446620        1.000000    -0.783356
# Temperature     0.058334  0.117773  0.448225       -0.783356     1.000000
